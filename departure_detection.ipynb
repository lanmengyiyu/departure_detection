# %%
# !git clone https://github.com/lanmengyiyu/departure_detection.git  # clone repo
# %cd departure_detection
# %pip install -qr requirements.txt  # install dependencies
# Out:
# fatal: destination path 'departure_detection' already exists and is not an empty directory.
# /content/departure_detection
#      |████████████████████████████████| 276kB 12.2MB/s
# ...

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.5 --source "/content/drive/My Drive/video/departure_detection.avi"
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (24811/29808) /content/drive/My Drive/video/departure_detection.avi: 384x640 4 persons, 4 chairs, 4 tvs, 3 keyboards, Done. (0.020s)
# video 1/1 (24812/29808) /content/drive/My Drive/video/departure_detection.avi: 384x640 4 persons, 4 chairs, 4 tvs, 3 keyboards, Done. (0.018s)
# video 1/1 (24813/29808) /content/drive/My Drive/video/departure_detection.avi: 384x640 4 persons, 4 chairs, 4 tvs, 3 keyboards, Done. (0.018s)
# video 1/1 (24814/29808) /content/drive/My Drive/video/departure_detection.avi: 384x640 4 persons, 4 chairs, 4 tvs, 3 keyboards, 1 books, Done. (0.019s)
# video 1/1 (24815/29808) /content/drive/My Drive/video/departure_detection.avi: 384x640 4 persons, 4 chairs, 4 tvs, 3 keyboards, Done. (0.019s)
# video 1/1 (24816/29808) /content/drive/My Drive/video/departure_detection.avi: 384x640 4 persons, 4 chairs, 4 tvs, 3 keyboards, 1 books, Done. (0.019s)
# ...
